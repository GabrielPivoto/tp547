# %% [markdown]
# # Reproduzindo resultados do artigo escolhido

# %% [markdown]
# #### Importando as bibliotecas

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# #### Método para plotar as imagens

# %%
def plot_image(image):
    chosen_curve = mpimg.imread(image)
    plt.imshow(chosen_curve)
    plt.axis('off')  
    plt.show()

# %% [markdown]
# #### Plotando a primeira curva escolhida

# %%
plot_image("ChosenCurve1.png")

# %% [markdown]
# #### Reproduzindo a curva por meio de uma função exponencial

# %%
A = 96.31222146355297
B = -93.3607015459303
C = -0.023494455428541956

x = np.linspace(5, 800, 1000)
y =  A + B * np.exp(C * x)

plt.plot(x, y)
plt.ylim(0, 10**2)
plt.xlim(0, 800)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Reprodução por função exponencial')
plt.show()

# %% [markdown]
# #### Plotando a segunda curva escolhida

# %%
plot_image("ChosenCurve2.png")

# %% [markdown]
# #### Reproduzindo a curva por uma função exponencial

# %%
A = 0.7122413456163222
B = -0.5393609372643366
C = -0.02681765051802024

x = np.linspace(5, 800, 1000)
y =  A + B * np.exp(C * x)

plt.plot(x, y)
plt.ylim(0, 1)
plt.xlim(0, 800)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Reprodução por função exponencial')
plt.show()
